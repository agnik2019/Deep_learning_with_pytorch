# %% [markdown]
# # Programming Assignment 02 [50 marks]
#
#
# This assignment will introduce you to implement and train a `Vision Transformer (ViT)` which was covered in the class. Here, we will code all the building blocks and integrate all of them to build the complete model. We will mostly follow the skeletal notebook from the PA-01.
#
#
# This code has been tested and should run for Python 3.7.10 with pytorch 1.7.0 and pytorch_lightning 1.2.0 in Google colab. The advantage of colab is that you can use GPUs for small codes that does not need very long runtime.

# %% [markdown]
# Details: (double-click here to fill)
#
# Name: `Agnik Saha`
#
# Roll Number: `21CS60A01`

# %% [markdown]
# Make sure to go through all the comments and texts in this notebook, as they contain specific instructions to complete the assignment. You would need to submit a single `.ipynb` file. Write your codes only between the START and END markers. All the required outputs must be embedded in the notebook itself. Feel free to reach out to the TAs through Piazza if you have any doubts. Happy coding (and learning)!

# %% [markdown]
# ## Part 0: Tutorials
#
# You will find these tutorials on pytorch and pytorch_lightning useful:
#  - [Pytorch Tutorials](https://pytorch.org/tutorials/) - "Learn the Basics" is very good starter
#  - [Pytorch-lightning masterclass](https://www.youtube.com/playlist?list=PLaMu-SDt_RB5NUm67hU2pdE75j6KaIOv2) - around 140 minutes of videos
#  - [deep-learning-project-template](https://github.com/PyTorchLightning/deep-learning-project-template/blob/master/project/lit_image_classifier.py) - You will find this project template from the official pytorch-lightning repo very useful. We have, mostly, tried to follow this template for this assignment.
#  - If you want to read more about vision transformers, here's the link to the paper: https://arxiv.org/pdf/2010.11929v2.pdf

# %% [markdown]
# ## Part 1: Building and training a Vision Transformer Model (ViT)

# %% [markdown]
# First, get the data to the working folder. We will only use the tiny-ImageNet dataset, whose drive link is as follows (the same link which was given for assignment-1):
#
# Tiny ImageNet - https://drive.google.com/file/d/1VO2ooFlzw6VD2P5hx535V0Rlbo9C6ldc/view?usp=sharing

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Copy data from drive

# %%
# copy the data and unzip it in the working folder
# !scp /content/drive/MyDrive/Tiny_ImageNet_200.zip ./
# !unzip Tiny_ImageNet_200.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_406.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_388.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_440.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_410.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_261.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_216.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_401.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_252.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_450.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_467.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_468.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_37.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_361.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_20.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_208.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_232.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_244.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_339.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_316.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_95.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_159.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_33.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_169.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_354.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_433.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_78.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_481.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_166.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_336.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_421.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_446.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_455.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_26.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_480.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_227.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_172.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_451.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_198.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_331.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_306.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_394.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_385.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_73.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_79.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_47.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_233.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_443.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_303.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_279.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_492.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_260.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_70.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_363.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_16.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_362.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_231.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_160.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_154.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_90.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_102.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_305.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_415.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_395.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_94.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_404.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_479.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_51.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_283.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_148.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_52.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_302.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_368.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_225.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_253.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_460.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_206.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_247.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_301.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_469.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_383.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_297.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_170.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_204.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_242.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_349.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_359.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_289.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_30.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_44.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_256.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_39.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_397.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_265.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_48.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_237.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_266.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_428.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_444.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_409.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_466.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_369.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_134.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_308.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_398.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_116.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_125.JPEG
#  extracting: Tiny-ImageNet-200/n02699494/images/n02699494_161.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_268.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_143.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_474.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_226.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_321.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_319.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_27.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_407.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_4.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_167.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_271.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_267.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_347.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_127.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_270.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_329.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_391.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_62.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_185.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_31.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_155.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_21.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_286.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_372.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_323.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_214.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_101.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_120.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_249.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_317.JPEG
#  extracting: Tiny-ImageNet-200/n02699494/images/n02699494_411.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_493.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_462.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_124.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_465.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_490.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_229.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_174.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_123.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_402.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_352.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_42.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_274.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_86.JPEG
#  extracting: Tiny-ImageNet-200/n02699494/images/n02699494_475.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_142.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_146.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_380.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_313.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_424.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_65.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_211.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_109.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_149.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_104.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_157.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_103.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_36.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_199.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_107.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_463.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_147.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_340.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_163.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_333.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_325.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_344.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_239.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_430.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_284.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_141.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_68.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_262.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_219.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_277.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_28.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_399.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_327.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_332.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_334.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_186.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_245.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_422.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_129.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_291.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_300.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_365.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_6.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_434.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_470.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_75.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_426.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_491.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_392.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_118.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_22.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_382.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_132.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_251.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_18.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_439.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_76.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_188.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_213.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_156.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_24.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_431.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_299.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_8.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_195.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_197.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_425.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_182.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_351.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_15.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_258.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_328.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_209.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_309.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_115.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_429.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_330.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_0.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_416.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_381.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_445.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_322.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_93.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_66.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_106.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_364.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_3.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_190.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_126.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_320.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_217.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_280.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_457.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_40.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_92.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_205.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_121.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_189.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_485.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_196.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_375.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_230.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_23.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_473.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_307.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_45.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_298.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_81.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_223.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_222.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_449.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_136.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_275.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_418.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_287.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_71.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_350.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_212.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_99.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_294.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_377.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_435.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_376.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_60.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_312.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_117.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_292.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_218.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_315.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_459.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_471.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_74.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_194.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_263.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_414.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_293.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_184.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_420.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_257.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_61.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_276.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_255.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_11.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_478.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_221.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_240.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_374.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_403.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_12.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_111.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_150.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_128.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_122.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_489.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_105.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_41.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_342.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_192.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_50.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_278.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_269.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_413.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_448.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_176.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_67.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_91.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_288.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_326.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_158.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_162.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_341.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_14.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_453.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_487.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_13.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_85.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_370.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_254.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_477.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_135.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_241.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_272.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_19.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_168.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_393.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_38.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_360.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_89.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_87.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_304.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_390.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_499.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_207.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_228.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_496.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_259.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_5.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_100.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_164.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_131.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_183.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_324.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_236.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_215.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_69.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_234.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_29.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_345.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_454.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_494.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_482.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_338.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_139.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_432.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_389.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_210.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_191.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_476.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_181.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_83.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_152.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_486.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_119.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_290.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_452.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_378.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_178.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_497.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_220.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_179.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_140.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_49.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_9.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_246.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_54.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_7.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_235.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_64.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_63.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_133.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_175.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_112.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_400.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_472.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_348.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_98.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_464.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_10.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_238.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_353.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_153.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_32.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_314.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_137.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_82.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_202.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_35.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_55.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_357.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_200.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_77.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_438.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_412.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_224.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_80.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_243.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_17.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_248.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_201.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_145.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_193.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_2.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_187.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_346.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_84.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_458.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_447.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_371.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_285.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_498.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_1.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_108.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_97.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_483.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_373.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_437.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_151.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_250.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_441.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_386.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_165.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_311.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_417.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_387.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_203.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_138.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_423.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_318.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_273.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_310.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_46.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_358.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_495.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_396.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_337.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_335.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_343.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_88.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_427.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_177.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_366.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_384.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_442.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_264.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_456.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_34.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_58.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_408.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_461.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/images/n02699494_130.JPEG
#   inflating: Tiny-ImageNet-200/n02699494/n02699494_boxes.txt
#    creating: Tiny-ImageNet-200/n07711569/
#    creating: Tiny-ImageNet-200/n07711569/images/
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_88.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_222.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_143.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_483.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_145.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_315.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_290.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_361.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_373.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_227.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_132.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_351.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_450.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_211.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_294.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_103.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_226.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_7.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_265.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_219.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_309.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_475.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_345.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_141.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_150.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_419.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_29.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_330.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_436.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_148.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_215.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_494.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_439.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_2.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_333.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_438.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_181.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_125.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_105.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_308.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_243.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_260.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_377.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_87.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_66.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_244.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_453.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_408.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_192.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_131.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_28.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_389.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_240.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_286.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_67.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_326.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_411.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_409.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_138.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_280.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_178.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_350.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_273.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_346.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_156.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_124.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_90.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_312.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_36.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_239.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_413.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_493.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_405.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_423.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_84.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_99.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_190.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_60.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_490.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_151.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_298.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_5.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_353.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_451.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_343.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_467.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_248.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_100.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_27.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_214.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_300.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_341.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_25.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_464.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_381.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_466.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_43.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_420.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_262.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_21.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_495.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_488.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_435.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_272.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_258.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_259.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_16.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_324.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_210.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_153.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_69.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_42.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_375.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_478.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_325.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_96.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_359.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_486.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_322.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_233.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_406.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_441.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_171.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_149.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_282.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_362.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_336.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_337.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_55.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_220.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_30.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_379.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_193.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_331.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_404.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_140.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_115.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_11.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_369.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_480.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_332.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_83.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_376.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_482.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_484.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_13.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_19.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_123.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_209.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_17.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_249.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_71.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_225.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_395.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_498.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_175.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_355.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_431.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_236.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_94.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_180.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_354.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_37.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_196.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_293.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_374.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_264.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_255.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_228.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_167.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_275.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_291.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_10.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_407.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_434.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_117.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_459.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_172.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_393.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_91.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_41.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_481.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_329.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_111.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_382.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_263.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_198.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_460.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_455.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_388.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_394.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_458.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_64.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_51.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_144.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_89.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_113.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_428.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_44.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_164.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_473.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_238.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_424.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_107.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_118.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_122.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_136.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_445.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_321.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_253.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_177.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_310.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_119.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_412.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_4.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_443.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_245.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_15.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_93.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_20.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_432.JPEG
#   inflating: Tiny-ImageNet-200/n07711569/images/n07711569_62.JPEG
# ...
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_28.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_458.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_418.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_7.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_396.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_348.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_383.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_361.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_304.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_305.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_306.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_436.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_302.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_382.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_233.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_121.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_360.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_134.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_423.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_52.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_19.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_472.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_32.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_312.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_260.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_311.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_317.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_77.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_276.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_140.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_277.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_57.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_105.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_45.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_205.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_321.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_359.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_173.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_498.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_426.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_392.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_251.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_487.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_290.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_329.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_363.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_236.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_112.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_356.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_122.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_440.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_222.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_150.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_336.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_330.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_46.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_245.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_83.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_26.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_323.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_324.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_64.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_3.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_20.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_488.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_444.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_318.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_416.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_125.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_99.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_216.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_398.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_203.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_89.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_333.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_132.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_104.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_47.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_240.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_244.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_295.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_208.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_232.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_256.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_91.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_411.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_281.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_267.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_162.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_393.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_51.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_169.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_44.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_152.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_58.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_492.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_455.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_446.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_79.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_390.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_257.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_227.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_459.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_280.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_457.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_337.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_453.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_314.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_213.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_410.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_16.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_136.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_299.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_102.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_158.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_288.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_265.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_37.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_422.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_350.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_375.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_325.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_497.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_27.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_342.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_186.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_62.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_72.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_355.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_424.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_284.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_252.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_475.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_381.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_84.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_103.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_248.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_439.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_185.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_214.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_107.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_101.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_272.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_278.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_11.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_466.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_43.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_38.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_117.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_141.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_404.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_15.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_14.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_18.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_255.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_225.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_451.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_385.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_345.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_370.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_190.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_296.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_48.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_441.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_308.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_119.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_379.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_25.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_483.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_262.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_68.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_127.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_55.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_343.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_189.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_9.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_100.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_369.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_207.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_249.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_71.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_41.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_263.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_326.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_75.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_429.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_368.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_450.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_88.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_420.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_22.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_123.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_180.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_269.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_95.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_334.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_109.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_258.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_63.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_70.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_163.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_395.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_4.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_491.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_200.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_254.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_387.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_17.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_473.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_253.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_145.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_166.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_65.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_93.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_401.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_219.JPEG
#  extracting: Tiny-ImageNet-200/n06596364/images/n06596364_78.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_2.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_338.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_327.JPEG
#  extracting: Tiny-ImageNet-200/n06596364/images/n06596364_495.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_315.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_218.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_341.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_403.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_380.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_282.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_168.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_344.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_287.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/images/n06596364_362.JPEG
#   inflating: Tiny-ImageNet-200/n06596364/n06596364_boxes.txt

# %% [markdown]
# Install the required dependencies

# %%
# install pytorch lighting
! pip install pytorch-lightning --quiet
! pip install einops
# Out:
#      |████████████████████████████████| 582 kB 4.3 MB/s
#      |████████████████████████████████| 398 kB 40.3 MB/s
#      |████████████████████████████████| 134 kB 49.2 MB/s
#      |████████████████████████████████| 596 kB 37.5 MB/s
#      |████████████████████████████████| 1.1 MB 41.3 MB/s
#      |████████████████████████████████| 271 kB 51.7 MB/s
#      |████████████████████████████████| 94 kB 2.7 MB/s
#      |████████████████████████████████| 144 kB 51.1 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# arviz 0.11.4 requires typing-extensions<4,>=3.7.4.3, but you have typing-extensions 4.1.1 which is incompatible.
# Collecting einops
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Installing collected packages: einops
# Successfully installed einops-0.4.1

# %% [markdown]
# Import required libraries

# %%
# List of imports
from PIL import Image
from typing import Type, Any, Callable, Union, List, Optional

## PyTorch
import torch
from torch import Tensor
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
## PyTorch lightning
import pytorch_lightning as pl
import torchmetrics
# Torchvision
import torchvision
from torchvision import transforms

# import TensorBoardLogger
from pytorch_lightning.loggers import TensorBoardLogger

from math import sqrt

from einops import rearrange, repeat
from einops.layers.torch import Rearrange

# %% [markdown]
# The diagram shows the model overview of Vision Transformer. Given an image, we split into fixed-size patches, linearly embed each of them, add position embeddings, and feed the resulting sequence of vectors to a standard Transformer encoder. In order to perform classification, the standard approach of adding an extra learnable “classification token” to the sequence is used.
#
# Image courtesy: https://arxiv.org/pdf/2010.11929v2.pdf

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Code for various components of ViT

# %%
# helpers
def pair(t):
    return t if isinstance(t, tuple) else (t, t)

# %% [markdown]
# `[8 marks]`

# %%
# classes
class PreNorm(nn.Module):
    def __init__(self, dim, fn):
        super().__init__()
        self.norm = nn.LayerNorm(dim)
        self.fn = fn
    def forward(self, x, **kwargs):
        return self.fn(self.norm(x), **kwargs)

class FeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, dropout = 0.):
        super().__init__()
        ###################################
        ####   Code required (start)   ####
        ###################################
        # Declare a sequential network: 
        # linear [dim->hidden_dim], 
        # gelu activation,
        # dropout layer,
        # linear [hidden_dim, dim],
        # dropout layer
        
        self.net = nn.Sequential(
            nn.Linear(dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, dim),
            nn.Dropout(dropout)
        )  
        ###################################
        ####   Code required (end)   ####
        ###################################
  
    def forward(self, x):
        ###################################
        ####   Code required (start)   ####
        ###################################
        # Simply pass the input x through the declared network (1 line code)
        return self.net(x)
        ###################################
        ####   Code required (end)   ####
        ###################################

class Attention(nn.Module):
    def __init__(self, dim, heads = 8, dim_head = 64, dropout = 0.):
        super().__init__()
        # Multi-head attention block
        # All the required layers are declared here:
        inner_dim = dim_head *  heads
        project_out = not (heads == 1 and dim_head == dim)

        self.heads = heads
        self.scale = dim_head ** -0.5

        self.attend = nn.Softmax(dim = -1)
        self.to_qkv = nn.Linear(dim, inner_dim * 3, bias = False)

        self.to_out = nn.Sequential(
            nn.Linear(inner_dim, dim),
            nn.Dropout(dropout)
        ) if project_out else nn.Identity()

    def forward(self, x):
        ###################################
        ####   Code required (start)   ####
        ###################################
        # Implement the forward function by using all the declared layers above
        # Keeping track of the shape of the intermediate outputs can be handy in writing the code correctly
        # einops has a very cool rearrange feature: https://einops.rocks/api/rearrange/ you can use it here
        # The forward function should attend over the input x, and return the output
        qkv = self.to_qkv(x).chunk(3, dim = -1)
        q, k, v = map(lambda t: rearrange(t, 'b n (h d) -> b h n d', h = self.heads), qkv)

        dots = torch.matmul(q, k.transpose(-1, -2)) * self.scale

        attn = self.attend(dots)

        out = torch.matmul(attn, v)
        out = rearrange(out, 'b h n d -> b n (h d)')
        return self.to_out(out)
        ###################################
        ####   Code required (end)   ####
        ###################################

# %% [markdown]
# `[3 marks]`

# %%
class Transformer(nn.Module):
    def __init__(self, dim, depth, heads, dim_head, mlp_dim, dropout = 0.):
        super().__init__()
        self.layers = nn.ModuleList([])
        for _ in range(depth):
            self.layers.append(nn.ModuleList([
                PreNorm(dim, Attention(dim, heads = heads, dim_head = dim_head, dropout = dropout)),
                PreNorm(dim, FeedForward(dim, mlp_dim, dropout = dropout))
            ]))
    def forward(self, x):
        ###################################
        ####   Code required (start)   ####
        ###################################
        # Implement the forward function
        # Pass the input x through all the layers and return the output
        for attn, ff in self.layers:
            x = attn(x) + x
            x = ff(x) + x
        return x
        ###################################
        ####   Code required (end)   ####
        ###################################

# %% [markdown]
# `[20 marks]`

# %%
class ViT(nn.Module):
    def __init__(self, *, image_size, patch_size, num_classes, dim, depth, heads, mlp_dim, pool = 'cls', channels = 3, dim_head = 64, dropout = 0., emb_dropout = 0.):
        super().__init__()
        image_height, image_width = pair(image_size)
        patch_height, patch_width = pair(patch_size)

        ###################################
        ####   Code required (start)   ####
        ###################################
        # assert that image size is divisible by patch size (1 line of code)
        # compute number of patches (1 line of code)
        assert image_height % patch_height == 0 and image_width % patch_width == 0, 'image size is divisible by patch size.'
        num_patches = (image_height // patch_height) * (image_width // patch_width)
        ###################################
        ####   Code required (end)   ####
        ###################################
        
        patch_dim = channels * patch_height * patch_width
        assert pool in {'cls', 'mean'}, 'pool type must be either cls (cls token) or mean (mean pooling)'

        # patch to embedding
        self.to_patch_embedding = nn.Sequential(
            Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1 = patch_height, p2 = patch_width),
            nn.Linear(patch_dim, dim),
        )

        ###################################
        ####   Code required (start)   ####
        ###################################
        # Declare positional embedding and cls token
        # pos_embedding shape: 1, num_patches + 1, dim
        # cls_token shape: 1, 1, dim
        # both should be randomly intialized, and should be nn.Parameter to make them learnable
        self.pos_embedding = nn.Parameter(torch.randn(1, num_patches + 1, dim))
        self.cls_token = nn.Parameter(torch.randn(1, 1, dim))
        ###################################
        ####   Code required (end)   ####
        ###################################

        self.dropout = nn.Dropout(emb_dropout)

        self.transformer = Transformer(dim, depth, heads, dim_head, mlp_dim, dropout)

        self.pool = pool
        self.to_latent = nn.Identity()

        ###################################
        ####   Code required (start)   #### 
        ###################################
        # Declare the mlp head
        # Sequential of:
        # layernorm [dim]
        # linear [dim->num_classes]
        self.mlp_head =  nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, num_classes)
        )
        ###################################
        ####   Code required (end)   ####
        ###################################

        

    def forward(self, img):
        ###################################
        ####   Code required (start)   ####
        ###################################
        # Implement the forward function of the ViT
        # Use all the layers and components declared above
        # Keeping track of the input and output shapes of all the components is always handy for writing the forward function quickly
        x = self.to_patch_embedding(img)
        b, n, _ = x.shape

        cls_tokens = repeat(self.cls_token, '() n d -> b n d', b = b)
        x = torch.cat((cls_tokens, x), dim=1)
        x += self.pos_embedding[:, :(n + 1)]
        x = self.dropout(x)

        x = self.transformer(x)

        x = x.mean(dim = 1) if self.pool == 'mean' else x[:, 0]

        x = self.to_latent(x)
        return self.mlp_head(x)
        ###################################
        ####   Code required (end)   ####
        ###################################

# %% [markdown]
# `[8 marks]`

# %%
class My_ViT_Classifier(pl.LightningModule):
    def __init__(self, image_size=224, patch_size=16, num_classes=200, dim=192, depth=3, heads=12, mlp_dim=384, pool = 'cls', channels = 3, dim_head = 64, learning_rate=3e-3):
        '''
        image_size: dimension of image (224 x 224)
        patch_size: dimension of patches (16 x 16)        
        num_classes: Number of classes in the dataset (200 for tiny-Imagenet)
        dim: hidden dimension of the transformer
        depth: depth of the transformer
        heads: number of heads for multi-head attention
        mlp_dim: hidden dimension for mlp 
        dim_head: dimension of each head for attention        
        learning_rate: The learning rate hyperparameter

        Don't change any of these values
        '''
        super().__init__()
        # 'save_hyperparameters' saves the values of anything in the __init__ for us to the checkpoint.
        # This is a useful feature.
        self.save_hyperparameters()

        self.backbone = ViT(image_size=image_size, patch_size=patch_size, num_classes=num_classes, dim=dim, depth=depth, heads=heads, mlp_dim=mlp_dim, pool = pool, channels = channels, dim_head = dim_head)
        
        self.num_classes = num_classes
        self.accuracy = torchmetrics.Accuracy()
    
    def forward(self, x):
        ###################################
        ####   Code required (start)   ####
        ###################################
        # use forward for inference/predictions
        model = self.backbone
        x =  model(x)
        ###################################
        ####    Code required (end)    ####
        ###################################
        return x
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        logits = self.forward(x)
        loss = F.cross_entropy(logits, y)
        # Logging training loss on each training step and also on each epoch
        self.log('train_loss', loss, on_step=True, on_epoch=True, logger=True)
        
        ###################################
        ####   Code required (start)   ####
        ###################################
        # get the predictions, find accuracy, and log it.
        acc = self.accuracy(logits,y)
        self.log("train_acc", acc, on_step=True, on_epoch=True, prog_bar=True, logger=True)
        ###################################
        ####    Code required (end)    ####
        ###################################
        return loss
    
    def validation_step(self, batch, batch_idx):
        ###################################
        ####   Code required (start)   ####
        ###################################
        # Implement the validation step here.
        # Make sure to log the val_loss and val_acc as you did in the training step
        x, y = batch
        logits = self.forward(x)
        loss = F.cross_entropy(logits, y)
        acc = self.accuracy(logits,y)

         # perform logging
        self.log("val_loss", loss, on_epoch=True, prog_bar=True, logger=True)
        self.log("val_acc", acc, on_epoch=True, prog_bar=True, logger=True)

        ###################################
        ####    Code required (end)    ####
        ###################################

        return loss
    
    def test_step(self, batch, batch_idx):
        ###################################
        ####   Code required (start)   ####
        ###################################
        # Implement the test step here.
        # Make sure to log the test_loss and test_acc.
        # Code is very similar to that of the validation step.
        x, y = batch
        logits = self.forward(x)
        loss = F.cross_entropy(logits, y)
        acc = self.accuracy(logits,y)

        # perform logging
        self.log("test_loss", loss, on_step=True, prog_bar=True, logger=True)
        self.log("test_acc", acc, on_step=True, prog_bar=True, logger=True)

        ###################################
        ####    Code required (end)    ####
        ###################################
        return loss
    
    def configure_optimizers(self):
        # self.hparams available because we called self.save_hyperparameters()
        return optim.Adam(self.parameters(), lr=self.hparams.learning_rate)

# %% [markdown]
# Now, we will train ViT!

# %%
# Setting the seed for reproducibility
pl.seed_everything(101)

# ------------
# args
# ------------
# Path to the folder where the Tiny ImageNet dataset is/will be downloaded

DATASET_PATH = "/content/Tiny-ImageNet-200/"
# Choice of activation functions as dict

# ------------
# data
# ------------

# As we have learned in the class, it is important to have the data preprocessed with a zero mean. 
# The following values are the mean and std for tiny-imagenet:
DATA_MEANS = [0.485, 0.456, 0.406]
DATA_STD = [0.229, 0.224, 0.225]
print("Mean of data:", DATA_MEANS)
print("Standard deviation of data:", DATA_STD)

# We will use the mean and standard deviation of the input data computed above to normalize the input.

# Note that the above normalization will be applied to both test/valiadtion and traning data. The training data,
# in addition, will need to go through a few more data augmentations. We plan to use following data augmentations.
# 1. Random horizontal flip with 50% probability - RandomHorizontalFlip
# 2. Crop the image to random size and aspect ratio. This crop is finally resized to given size - RandomResizedCrop
train_transform = transforms.Compose([transforms.RandomHorizontalFlip(),
                                      transforms.RandomResizedCrop((224,224),scale=(0.8,1.0),ratio=(0.85,1.15)),
                                      transforms.ToTensor(),
                                      transforms.Normalize(DATA_MEANS, DATA_STD)
                                     ])

test_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Resize((224,224)),
                                     transforms.Normalize(DATA_MEANS, DATA_STD)
                                     ])
# Next we will split the training data into training and validation. You will notice that we use the same command
# in the next two lines. This is a trick, often used to make sure that training data uses the random data augmentations
# while validation data do not.

tiny_imagenet_dataset_train = torchvision.datasets.ImageFolder(root=DATASET_PATH, transform=train_transform)
tiny_imagenet_dataset_val_test = torchvision.datasets.ImageFolder(root=DATASET_PATH, transform=test_transform)
# declared the same thing multiple times because of different transforms. just a hack (inefficient though)
num_imgs = len(tiny_imagenet_dataset_train)
print("Total number of images:", num_imgs)

# Let's split the dataset as: train: 65%, val: 10%, test: 25%.
train_length = int(0.65*num_imgs)
val_length = int(0.1*num_imgs)
test_length = num_imgs - train_length - val_length

print(train_length, val_length, test_length)

train_set, _, _ = data.random_split(tiny_imagenet_dataset_train, [train_length, val_length, test_length])
_, val_set, test_set = data.random_split(tiny_imagenet_dataset_val_test, [train_length, val_length, test_length])

# Define a set of data loaders
train_loader = data.DataLoader(train_set, batch_size=128, shuffle=True, drop_last=True, pin_memory=True, num_workers=4)
val_loader = data.DataLoader(val_set, batch_size=128, shuffle=False, drop_last=False, num_workers=4)
test_loader = data.DataLoader(test_set, batch_size=128, shuffle=False, drop_last=False, num_workers=4)

# ------------
# model
# ------------
# We will use a ResNet-50 model for this assignment. 
# You may try experimenting with ResNet-101 and ResNet-152 to find out
# But, training these larger networks will demand more computation and memory requirements.
# the effect of depth in the performance of a neural network.
model = My_ViT_Classifier(num_classes=200, learning_rate=3e-3)
# ------------
# logging
# ------------
# Initialize Tensorboard logger
TensorBoard_Logger = TensorBoardLogger('/content/tb_logs', 'tiny-imagenet', 'ViT')

# ------------
# training
# ------------
# Initialize a trainer
trainer = pl.Trainer(max_epochs=40,
                    progress_bar_refresh_rate=20, 
                    gpus=1,
                    logger=TensorBoard_Logger)
# Out:
# Global seed set to 101
# Mean of data: [0.485, 0.456, 0.406]
# Standard deviation of data: [0.229, 0.224, 0.225]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:97: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=20)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   f"Setting `Trainer(progress_bar_refresh_rate={progress_bar_refresh_rate})` is deprecated in v1.5 and"
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Total number of images: 100000
# 65000 10000 25000

# %%
# Train the model
trainer.fit(model, train_loader, val_loader)
# expect a per epoch time taken to be around 3.5 minutes (on Colab using GPU backend)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type     | Params
# --------------------------------------
# 0 | backbone | ViT      | 2.4 M
# 1 | accuracy | Accuracy | 0
# --------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.764     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %% [markdown]
# [00:00<?, ?it/s, loss=4.61, v_num=ViT, train_acc_step=0.0938, val_loss=4.630, val_acc=0.0665, train_acc_epoch=0.0686]

# %% [markdown]
# `[2 marks]`

# %%
###################################
####   Code required (start)   ####
###################################
# Write the code to save the checkpoint
# and show the evaluation
# results on validation and test set
trainer.save_checkpoint("trained_model_vit.ckpt")
new_model = model.load_from_checkpoint(checkpoint_path="trained_model_vit.ckpt")
trainer.validate(dataloaders = val_loader)
trainer.test(dataloaders = test_loader)
###################################
####    Code required (end)    ####
###################################
# Out:
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1448: UserWarning: `.validate(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `validate(ckpt_path='best')` to use and best model checkpoint and avoid this warning or `ckpt_path=trainer.checkpoint_callback.last_model_path` to use the last model.
#   f"`.{fn}(ckpt_path=None)` was called without a model."
# Restoring states from the checkpoint path at /content/tb_logs/tiny-imagenet/ViT/checkpoints/epoch=39-step=20280.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from checkpoint at /content/tb_logs/tiny-imagenet/ViT/checkpoints/epoch=39-step=20280.ckpt
# Validation: 0it [00:00, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1448: UserWarning: `.test(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `test(ckpt_path='best')` to use and best model checkpoint and avoid this warning or `ckpt_path=trainer.checkpoint_callback.last_model_path` to use the last model.
#   f"`.{fn}(ckpt_path=None)` was called without a model."
# Restoring states from the checkpoint path at /content/tb_logs/tiny-imagenet/ViT/checkpoints/epoch=39-step=20280.ckpt
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#          val_acc            0.0632999986410141
#         val_loss             4.659012317657471
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from checkpoint at /content/tb_logs/tiny-imagenet/ViT/checkpoints/epoch=39-step=20280.ckpt
# Testing: 0it [00:00, ?it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      test_acc_epoch         0.06707999855279922
#      test_loss_epoch         4.640530109405518
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_acc_epoch': 0.06707999855279922, 'test_loss_epoch': 4.640530109405518}]

# %% [markdown]
# #Implementing Shifted Patch Token (SPT) for small datasets.

# %% [markdown]
# It is well known that ViTs are data hungry and underperform on small datasets like tiny-Imagenet. The paper https://arxiv.org/pdf/2112.13492.pdf proposed some specific modifications in this regard to improve performance of ViTs on small datasets. We would now implement one of the proposed components called "Shifted Patch Tokenization (SPT)" which is very simple and is discussed in the class.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Image courtesy and for further reading on Vision Transformers for small datasets: https://arxiv.org/pdf/2112.13492.pdf

# %% [markdown]
# We simply need to code a SPT class as follows:

# %% [markdown]
# `[5 marks]`

# %%
class SPT(nn.Module):
    def __init__(self, *, dim, patch_size, channels = 3):
        super().__init__()
        patch_dim = patch_size * patch_size * 5 * channels

        self.to_patch_tokens = nn.Sequential(
            Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1 = patch_size, p2 = patch_size),
            nn.LayerNorm(patch_dim),
            nn.Linear(patch_dim, dim)
        )

    def forward(self, x):
        shifts = ((1, -1, 0, 0), (-1, 1, 0, 0), (0, 0, 1, -1), (0, 0, -1, 1))
        ###################################
        ####   Code required (start)   ####
        ###################################
        # Implement the forward function by using the above declared layers
        shifted_x = list(map(lambda shift: F.pad(x, shift), shifts))
        x_with_shifts = torch.cat((x, *shifted_x), dim = 1)
        return self.to_patch_tokens(x_with_shifts)

        ###################################
        ####   Code required (end)   ####
        ###################################

# %% [markdown]
# `[1 mark]`

# %%
# Now we incorporate the SPT class in the ViT.
# The only change in the following code would be self.to_patch_embedding, which will now be SPT (highlighted below)
class ViT_with_SPT(nn.Module):
    def __init__(self, *, image_size, patch_size, num_classes, dim, depth, heads, mlp_dim, pool = 'cls', channels = 3, dim_head = 64, dropout = 0., emb_dropout = 0.):
        super().__init__()
        image_height, image_width = pair(image_size)
        patch_height, patch_width = pair(patch_size)

        ###################################
        ####   Code required (start)   #### [COPY THE CODE WHICH YOU WROTE ABOVE FOR THE CLASS ViT(). NO NEW CODE REQUIRED!]
        ###################################
        # assert that image size is divisible by patch size (1 line of code)
        # compute number of patches (1 line of code)
        assert image_height % patch_height == 0 and image_width % patch_width == 0, 'image size is divisible by patch size.'

        num_patches = (image_height // patch_height) * (image_width // patch_width)
        ###################################
        ####   Code required (end)   ####
        ###################################
        
        patch_dim = channels * patch_height * patch_width
        assert pool in {'cls', 'mean'}, 'pool type must be either cls (cls token) or mean (mean pooling)'

        # patch to embedding using SPT
        self.to_patch_embedding = SPT(dim = dim, patch_size = patch_size, channels = channels) ### ONLY CHANGE REQUIRED TO INCORPORATE SPT in ViT!

        ###################################
        ####   Code required (start)   #### [COPY THE CODE WHICH YOU WROTE ABOVE FOR THE CLASS ViT(). NO NEW CODE REQUIRED!]
        ###################################
        # Declare positional embedding and cls token
        # pos_embedding shape: 1, num_patches + 1, dim
        # cls_token shape: 1, 1, dim
        # both should be randomly intialized, and should be nn.Parameter
        self.pos_embedding = nn.Parameter(torch.randn(1, num_patches + 1, dim))
        self.cls_token = nn.Parameter(torch.randn(1, 1, dim))
        ###################################
        ####   Code required (end)   ####
        ###################################

        self.dropout = nn.Dropout(emb_dropout)

        self.transformer = Transformer(dim, depth, heads, dim_head, mlp_dim, dropout)

        self.pool = pool
        self.to_latent = nn.Identity()

        ###################################
        ####   Code required (start)   #### [COPY THE CODE WHICH YOU WROTE ABOVE FOR THE CLASS ViT(). NO NEW CODE REQUIRED!]
        ###################################
        # Declare the mlp head
        # Sequential of:
        # layernorm [dim]
        # linear [dim->num_classes]
        self.mlp_head = nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, num_classes)
        )
        ###################################
        ####   Code required (end)   ####
        ###################################

        

    def forward(self, img):
        ###################################
        ####   Code required (start)   #### [COPY THE CODE WHICH YOU WROTE ABOVE FOR THE CLASS ViT(). NO NEW CODE REQUIRED!]
        ###################################
        # Implement the forward function of the ViT
        # Use all the layers and components declared above
        # Keeping track of the input and output shapes of all the components is always handy for writing the forward function quickly
        x = self.to_patch_embedding(img)
        b, n, _ = x.shape

        cls_tokens = repeat(self.cls_token, '() n d -> b n d', b = b)
        x = torch.cat((cls_tokens, x), dim=1)
        x += self.pos_embedding[:, :(n + 1)]
        x = self.dropout(x)

        x = self.transformer(x)

        x = x.mean(dim = 1) if self.pool == 'mean' else x[:, 0]

        x = self.to_latent(x)
        return self.mlp_head(x)

        ###################################
        ####   Code required (end)   ####
        ###################################

# %% [markdown]
# PLEASE NOTE: THE FOLLOWING CODE BLOCKS DO NOT REQUIRE YOU TO WRITE ANY NEW CODES, SIMPLY COPY-PASTE THE CODES WHICH YOU HAVE WRITTEN FOR ViT ABOVE, and USE THEM TO TRAIN ViT_with_SPT :)

# %% [markdown]
# `[1 mark]`

# %%
class My_ViT_Classifier_with_SPT(pl.LightningModule):
    def __init__(self, image_size=224, patch_size=16, num_classes=200, dim=192, depth=3, heads=12, mlp_dim=384, pool = 'cls', channels = 3, dim_head = 64, learning_rate=3e-3):
        '''
        image_size: dimension of image (224 x 224)
        patch_size: dimension of patches (16 x 16)        
        num_classes: Number of classes in the dataset (200 for tiny-Imagenet)
        dim: hidden dimension of the transformer
        depth: depth of the transformer
        heads: number of heads for multi-head attention
        mlp_dim: hidden dimension for mlp 
        dim_head: dimension of each head for attention        
        learning_rate: The learning rate hyperparameter

        Don't change any of these values
        '''
        super().__init__()
        # 'save_hyperparameters' saves the values of anything in the __init__ for us to the checkpoint.
        # This is a useful feature.
        self.save_hyperparameters()

        self.backbone = ViT_with_SPT(image_size=image_size, patch_size=patch_size, num_classes=num_classes, dim=dim, depth=depth, heads=heads, mlp_dim=mlp_dim, pool = pool, channels = channels, dim_head = dim_head)
        
        self.num_classes = num_classes
        self.accuracy = torchmetrics.Accuracy()
    
    def forward(self, x):
        ###################################
        ####   Code required (start)   #### [COPY THE CODE WHICH YOU WROTE ABOVE FOR THE CLASS ViT(). NO NEW CODE REQUIRED!]
        ###################################
        # use forward for inference/predictions
        model = self.backbone
        x =  model(x)
        ###################################
        ####    Code required (end)    ####
        ###################################
        return x
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        logits = self.forward(x)
        loss = F.cross_entropy(logits, y)
        # Logging training loss on each training step and also on each epoch
        self.log('train_loss', loss, on_step=True, on_epoch=True, logger=True)
        
        ###################################
        ####   Code required (start)   #### [COPY THE CODE WHICH YOU WROTE ABOVE FOR THE CLASS ViT(). NO NEW CODE REQUIRED!]
        ###################################
        # get the predictions, find accuracy, and log it.
        acc = self.accuracy(logits,y)
        self.log("train_acc", acc, on_step=True, on_epoch=True, prog_bar=True, logger=True)
        ###################################
        ####    Code required (end)    ####
        ###################################
        return loss
    
    def validation_step(self, batch, batch_idx):
        ###################################
        ####   Code required (start)   #### [COPY THE CODE WHICH YOU WROTE ABOVE FOR THE CLASS ViT(). NO NEW CODE REQUIRED!]
        ###################################
        # Implement the validation step here.
        # Make sure to log the val_loss and val_acc as you did in the training step
        x, y = batch
        logits = self.forward(x)
        loss = F.cross_entropy(logits, y)
        acc = self.accuracy(logits,y)

         # perform logging
        self.log("val_loss", loss, on_epoch=True, prog_bar=True, logger=True)
        self.log("val_acc", acc, on_epoch=True, prog_bar=True, logger=True)
        
        ###################################
        ####    Code required (end)    ####
        ###################################

        return loss
    
    def test_step(self, batch, batch_idx):
        ###################################
        ####   Code required (start)   #### [COPY THE CODE WHICH YOU WROTE ABOVE FOR THE CLASS ViT(). NO NEW CODE REQUIRED!]
        ###################################
        # Implement the test step here.
        # Make sure to log the test_loss and test_acc.
        # Code is very similar to that of the validation step.
        x, y = batch
        logits = self.forward(x)
        loss = F.cross_entropy(logits, y)
        acc = self.accuracy(logits,y)

        # perform logging
        self.log("test_loss", loss, on_step=True, prog_bar=True, logger=True)
        self.log("test_acc", acc, on_step=True, prog_bar=True, logger=True)       
        ###################################
        ####    Code required (end)    ####
        ###################################
        return loss
    
    def configure_optimizers(self):
        # self.hparams available because we called self.save_hyperparameters()
        return optim.Adam(self.parameters(), lr=self.hparams.learning_rate)

# %% [markdown]
# Now, we will train ViT with SPT and observe the difference in the performance

# %%
# Setting the seed for reproducibility
pl.seed_everything(101)

# ------------
# args
# ------------
# Path to the folder where the Tiny ImageNet dataset is/will be downloaded

DATASET_PATH = "/content/Tiny-ImageNet-200/"
# Choice of activation functions as dict

# ------------
# data
# ------------

# As we have learned in the class, it is important to have the data preprocessed with a zero mean. 
# The following values are the mean and std for tiny-imagenet:
DATA_MEANS = [0.485, 0.456, 0.406]
DATA_STD = [0.229, 0.224, 0.225]
print("Mean of data:", DATA_MEANS)
print("Standard deviation of data:", DATA_STD)

# We will use the mean and standard deviation of the input data computed above to normalize the input.

# Note that the above normalization will be applied to both test/valiadtion and traning data. The training data,
# in addition, will need to go through a few more data augmentations. We plan to use following data augmentations.
# 1. Random horizontal flip with 50% probability - RandomHorizontalFlip
# 2. Crop the image to random size and aspect ratio. This crop is finally resized to given size - RandomResizedCrop
train_transform = transforms.Compose([transforms.RandomHorizontalFlip(),
                                      transforms.RandomResizedCrop((224,224),scale=(0.8,1.0),ratio=(0.85,1.15)),
                                      transforms.ToTensor(),
                                      transforms.Normalize(DATA_MEANS, DATA_STD)
                                     ])

test_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Resize((224,224)),
                                     transforms.Normalize(DATA_MEANS, DATA_STD)
                                     ])
# Next we will split the training data into training and validation. You will notice that we use the same command
# in the next two lines. This is a trick, often used to make sure that training data uses the random data augmentations
# while validation data do not.

tiny_imagenet_dataset_train = torchvision.datasets.ImageFolder(root=DATASET_PATH, transform=train_transform)
tiny_imagenet_dataset_val_test = torchvision.datasets.ImageFolder(root=DATASET_PATH, transform=test_transform)
# declared the same thing multiple times because of different transforms. just a hack (inefficient though)
num_imgs = len(tiny_imagenet_dataset_train)
print("Total number of images:", num_imgs)

# Let's split the dataset as: train: 65%, val: 10%, test: 25%.
train_length = int(0.65*num_imgs)
val_length = int(0.1*num_imgs)
test_length = num_imgs - train_length - val_length

print(train_length, val_length, test_length)

train_set, _, _ = data.random_split(tiny_imagenet_dataset_train, [train_length, val_length, test_length])
_, val_set, test_set = data.random_split(tiny_imagenet_dataset_val_test, [train_length, val_length, test_length])

# Define a set of data loaders
train_loader = data.DataLoader(train_set, batch_size=128, shuffle=True, drop_last=True, pin_memory=True, num_workers=4)
val_loader = data.DataLoader(val_set, batch_size=128, shuffle=False, drop_last=False, num_workers=4)
test_loader = data.DataLoader(test_set, batch_size=128, shuffle=False, drop_last=False, num_workers=4)

# ------------
# model
# ------------
# We will use a ResNet-50 model for this assignment. 
# You may try experimenting with ResNet-101 and ResNet-152 to find out
# But, training these larger networks will demand more computation and memory requirements.
# the effect of depth in the performance of a neural network.
model = My_ViT_Classifier_with_SPT(num_classes=200, learning_rate=3e-3)
# ------------
# logging
# ------------
# Initialize Tensorboard logger
TensorBoard_Logger = TensorBoardLogger('/content/tb_logs', 'tiny-imagenet', 'ViT_with_SPT')

# ------------
# training
# ------------
# Initialize a trainer
trainer = pl.Trainer(max_epochs=40,
                    progress_bar_refresh_rate=20, 
                    gpus=1,
                    logger=TensorBoard_Logger)
# Out:
# Global seed set to 101
# Mean of data: [0.485, 0.456, 0.406]
# Standard deviation of data: [0.229, 0.224, 0.225]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:97: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=20)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   f"Setting `Trainer(progress_bar_refresh_rate={progress_bar_refresh_rate})` is deprecated in v1.5 and"
# GPU available: True, used: True
# Total number of images: 100000
# 65000 10000 25000
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
# Train the model
trainer.fit(model, train_loader, val_loader)
# expect a per epoch time taken to be around 3.5 minutes (on Colab using GPU backend)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type         | Params
# ------------------------------------------
# 0 | backbone | ViT_with_SPT | 3.0 M
# 1 | accuracy | Accuracy     | 0
# ------------------------------------------
# 3.0 M     Trainable params
# 0         Non-trainable params
# 3.0 M     Total params
# 12.154    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %% [markdown]
#  At,epoch 36.....train_acc_step=0.438, val_loss=2.650, val_acc=0.381, train_acc_epoch=0.396

# %% [markdown]
# `[1 mark]`

# %%
###################################
####   Code required (start)   ####
###################################
# Write the code to save the checkpoint
# and show the evaluation
# results on validation and test set
trainer.save_checkpoint("trained_model_vit_spt.ckpt")
new_model = model.load_from_checkpoint(checkpoint_path="trained_model_vit_spt.ckpt")
trainer.validate(dataloaders = val_loader)
trainer.test(dataloaders = test_loader)
###################################
####    Code required (end)    ####
###################################

# %%
# Show tensorboard plots
# %reload_ext tensorboard
# %tensorboard --logdir /content/tb_logs/

# %% [markdown]
# `[1 mark]`

# %% [markdown]
# ## What difference in the performance did you observe?
#
# Fill in the blanks:
#
# Performance of ViT:  `0.0632999986410141`
#
# Performance of ViT with SPT:  `0.381`
#
# Write 1-2 lines on the differences you observed while training both the models. (e.g. training time, convergence, etc.)
# I have got less performance in ViT with SPT as the epoch size was 33
